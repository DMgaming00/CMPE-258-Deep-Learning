# %% [markdown]
# # KerasCV Augmentation\n## Overview\nModern CV augmentation pipelines.\n

# %%
import tensorflow as tf\nfrom keras_cv import layers as cv_layers\n

# %% [markdown]
# ## KerasCV Augmentation\nRandomCutout, RandomContrast, RandomZoom.\n

# %%
model = tf.keras.Sequential([\n  cv_layers.RandomCutout(0.2, 0.2)\n])\n
