# %% [markdown]
# # Video Augmentation\n## Overview\nVideo augmentations using python.\n

# %%
import cv2\nimport numpy as np\n# For AugLy: import augly.video as vidaugs\n

# %% [markdown]
# ## Video Augmentation\nDemonstrating frame dropping, noise, blur.\n

# %%
# augly.video.blur(video_path, out_path, sigma=5.0)\n
