# %% [markdown]
# # Document Image Augmentation\n## Overview\nSimulating poor scans.\n

# %%
import cv2\nimport numpy as np\nimport matplotlib.pyplot as plt\n

# %% [markdown]
# ## Document Image Augmentation\nPerspective distortion and contrast to simulate scannings.\n

# %%
img = np.ones((100, 100)) * 255\nplt.imshow(img, cmap='gray')\n
